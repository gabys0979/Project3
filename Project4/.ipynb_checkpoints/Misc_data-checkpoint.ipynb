# %%
# Import dependencies
import pandas as pd

# %%
misc_22 = pd.read_csv("Misc_data/2022_misc.csv") 
misc_21 = pd.read_csv("Misc_data/2021_misc.csv") 
misc_19 = pd.read_csv("Misc_data/2019_misc.csv") 
misc_18 = pd.read_csv("Misc_data/2018_misc.csv") 
misc_17 = pd.read_csv("Misc_data/2017_misc.csv") 
misc_16 = pd.read_csv("Misc_data/2016_misc.csv") 
misc_15 = pd.read_csv("Misc_data/2015_misc.csv")

misc = [misc_15,misc_16,misc_17,misc_18,misc_19,misc_21,misc_22]

# %%
misc_22.head(30)
# Out:
#                        Tm  Attendance  Attend/G  BatAge  PAge  BPF  PPF  #HOF  \
# 0    Arizona Diamondbacks     1605199     19817    26.5  30.0   98   99     0
# 1          Atlanta Braves     3129931     38641    27.5  30.0  105  103     0
# 2       Baltimore Orioles     1368367     16893    27.0  27.7   99  100     0
# 3          Boston Red Sox     2625089     32409    28.8  30.2  108  108     0
# 4            Chicago Cubs     2616780     32306    27.9  29.5  103  103     0
# 5       Chicago White Sox     2009359     24807    29.3  29.6  101  101     0
# 6         Cincinnati Reds     1395770     17232    29.4  27.9  107  108     0
# 7     Cleveland Guardians     1295870     15998    25.9  26.3   98   97     0
# 8        Colorado Rockies     2597428     32067    29.0  29.1  112  114     0
# 9          Detroit Tigers     1575544     19214    27.9  27.5   99  100     0
# 10         Houston Astros     2688998     33198    29.3  29.4  100   98     0
# ...

# %%
Misc_data = pd.concat([misc_22,misc_21,misc_19,misc_18,misc_17,misc_16,misc_15])

# %%
Misc_data.head(50)
# Out:
#                        Tm Attendance Attend/G  BatAge  PAge  BPF  PPF  #HOF  \
# 0    Arizona Diamondbacks    1605199    19817    26.5  30.0   98   99     0
# 1          Atlanta Braves    3129931    38641    27.5  30.0  105  103     0
# 2       Baltimore Orioles    1368367    16893    27.0  27.7   99  100     0
# 3          Boston Red Sox    2625089    32409    28.8  30.2  108  108     0
# 4            Chicago Cubs    2616780    32306    27.9  29.5  103  103     0
# 5       Chicago White Sox    2009359    24807    29.3  29.6  101  101     0
# 6         Cincinnati Reds    1395770    17232    29.4  27.9  107  108     0
# 7     Cleveland Guardians    1295870    15998    25.9  26.3   98   97     0
# 8        Colorado Rockies    2597428    32067    29.0  29.1  112  114     0
# 9          Detroit Tigers    1575544    19214    27.9  27.5   99  100     0
# 10         Houston Astros    2688998    33198    29.3  29.4  100   98     0
# ...

# %%
Misc_data.to_csv("Misc_data/Misc_data7yrs.csv")
